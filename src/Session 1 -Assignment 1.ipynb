# %% [markdown]
# # Session 1: Assignment 1
# ## 1 Introduction
#     This assignment will help you to consolidate the concepts learnt in the session.
#
# ## 2 Problem Statement
#
# ### Task 1
#
# #### 1. Install Jupyter notebook and run the first program and share the screenshot of the output.

# %%
print('This is a first program!')
# Out:
# This is a first program!

# %% [markdown]
# #### 2. Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
numbers = []
for n in range (2000, 3201):
    if n%7 == 0 and n%5 !=0:
        numbers.append(n)
#print('List of numbers divisible by 7, but not a multiple of 5 are below. \n{}'.format(numbers)) 

print(*numbers, sep=',')
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199

# %% [markdown]
# #### 3. Write a Python program to accept the user's first and last name and then getting them printed in the the reverse order with a space between first name and last name.

# %%
first_name = input('Enter the first name:')
last_name  = input('Enter the last name:')
print("{} {}".format(last_name,first_name))
# Out:
# Enter the first name:Mike
# Enter the last name:foo
# foo Mike

# %% [markdown]
# #### 4.Write a Python program to find the volume of a sphere with diameter 12 cm.
#    **`Formula: V=4/3 * π * r 3`**

# %%
PI = 3.14
diameter = 12
r = diameter/2
volume = 4/3 * PI * (r ** 3)

print ("Volume of sphere having diameter {}cm is {}cm3.".format(diameter, round(volume,2)))
# Out:
# Volume of sphere having diameter 12cm is 904.32cm3.

# %% [markdown]
# ### Task 2
# #### 1. Write a program which accepts a sequence of comma-separated numbers from console and generate a list.

# %%
numbers = input("Enter comma separated numbers:")
numbers_list = []
for n in numbers.split(','):
    if n.isnumeric():
        numbers_list.append(int(n))
        
print('Numbers as list\n',numbers_list)
# Out:
# Enter comma separated numbers:22,33,11,100,20,33
# Numbers as list
#  [22, 33, 11, 100, 20, 33]

# %% [markdown]
# #### 2. Create the below pattern using nested for loop in Python.
# `*`
# <br>`**`
# <br>`***`
# <br>`****`
# <br>`*****`
# <br>`****`
# <br>`***`
# <br>`**`
# <br>`*`

# %%
c = '*'
n = 10
m = n//2 + 1
for i in range(n):
    if i < m:
        for j in range(i):
            print(c, end = '')
            j = j + 1
        print("")    
    else: 
        for j in range(n, i, -1):
            print(c, end = '')
            j = j - 1     
        print("")
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
# Another way of doing it for my understanding
c = '*'
n = 10
m = n//2 + 1
for i in range(n):
    if i < m:
        print(c*i)   
    else: 
         print(c*(n-i))
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# #### 3.Write a Python program to reverse a word after accepting the input from the user.
# **Sample Output:**
# <br>Input word: AcadGild
# <br>Output: dilGdacA

# %%
word = input("Input word:")
print('Output:', word[::-1])
# Out:
# Input word:AcadGild
# Output: dliGdacA

# %% [markdown]
# #### 4.Write a Python Program to print the given string in the format specified in the ​sample output.
# <br>WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a
# <br>SOVEREIGN, SOCIALIST, SECULAR, <br>DEMOCRATIC REPUBLIC and to secure to all
# <br>its citizens
# ![Screenshot%202020-05-10%20at%208.42.52%20PM.png](attachment:Screenshot%202020-05-10%20at%208.42.52%20PM.png)

# %%
print("WE, THE PEOPLE OF INDIA,")
print("\t".expandtabs(6)+"having solemnly resolved to constitute India into a SOVEREIGN, !")
print("\t".expandtabs(12)+"SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC")
print("\t".expandtabs(13)+"and to secure to all its citizens")
# Out:
# WE, THE PEOPLE OF INDIA,
#       having solemnly resolved to constitute India into a SOVEREIGN, !
#             SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
#              and to secure to all its citizens

# %% [markdown]
# ## 3. Output
# N/A
